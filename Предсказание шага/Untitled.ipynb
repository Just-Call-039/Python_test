# %%
import pandas as pd

df_1 = pd.read_csv("Total_data.csv", sep=";")
df_1.head(30)
# Out:
#             steps  positive  negative  chance  amount
# 0        [83,3,2]         5        52    0.91     NaN
# 1         [4,4,2]       448      4791    0.91     NaN
# 2     [25,23,101]       107       419    0.80     NaN
# 3     [250,78,31]         4        21    0.84     NaN
# 4   [250,105,107]       236      1139    0.83     NaN
# 5     [26,250,13]        13        87    0.87     NaN
# 6      [8,16,111]         5        57    0.92     NaN
# 7    [261,90,101]        43       157    0.79     NaN
# 8    [250,261,65]        28       103    0.79     NaN
# 9     [56,91,103]        41        92    0.69     NaN
# 10    [65,94,111]         0         3    1.00     NaN
# 11    [12,10,102]       416      2148    0.84     NaN
# 12   [199,95,103]         0         3    1.00     NaN
# 13      [2,16,97]         6        14    0.70     NaN
# 14    [12,102,12]       120       409    0.77     NaN
# 15    [106,7,112]        37       108    0.74     NaN
# ...
